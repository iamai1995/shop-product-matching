# %%
# import libraries
import pandas as pd
import numpy as np
import random as random
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image

# %%
# load the training data
train = pd.read_csv('train.csv')
train.head(2)
# Out:
#          posting_id                                 image       image_phash  \
# 0   train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1  train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
#
#                                                title  label_group
# 0                          Paper Bag Victoria Secret    249114794
# 1  Double Tape 3M VHB 12 mm x 4,5 m ORIGINAL / DO...   2937985045

# %%
img_path = 'train_images/'

# let's see the image
Image.open(img_path+train['image'][0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F17CE24BDC0>

# %% [markdown]
# # Dataframe to image

# %%
np.uint8
# Out:
# numpy.uint8

# %%
# load the training data
img_df = pd.read_csv("shopee_images.csv", delimiter=",", engine='c', na_filter=False, dtype=np.uint8)

# %%
img_df.head(2)
# Out:
#    label_group                                 image    0    1    2    3    4  \
# 0    249114794  0000a68812bc7e98c42888dfb1c07da0.jpg  143   73   83  150   85
# 1   2937985045  00039780dfc94d01db8676fe789ecd05.jpg  255  255  255  255  255
#
#      5    6    7  ...  12278  12279  12280  12281  12282  12283  12284  12285  \
# 0   95  153   88  ...    142    194    116    134    191    111    129    193
# 1  255  255  255  ...    255    255    255    255    255    255    255    255
#
#    12286  12287
# 0    122    143
# 1    255    255
#
# [2 rows x 12290 columns]

# %%
y = img_df['image']

# %%
X = img_df.drop(columns = {"label_group", "image"})

# %%
X_ar = X.to_numpy()

# %%
# convert the image to array
X0 = X_ar[0].reshape([64,64,3])
plt.imshow(X0)

# %% [markdown]
# # Calling images

# %%
train.shape
# Out:
# (34250, 5)

# %%
img_df.shape
# Out:
# (34250, 12290)

# %%
random_numbers = np.random.randint(0, 34250, 10)
random_numbers
# Out:
# array([32243, 24046, 11484, 11299, 20145, 11313, 27210,  4274, 23639,
#         3497])

# %%
for i in random_numbers:
  print(y[i])
  print(train['image'][i])
# Out:
# f1af9e671d9b24c05907297f83831ecf.jpg
# f1af9e671d9b24c05907297f83831ecf.jpg
# b41041433e9d7900c927fbd1146f3240.jpg
# b41041433e9d7900c927fbd1146f3240.jpg
# 565934f763506640131fa6113671e514.jpg
# 565934f763506640131fa6113671e514.jpg
# 54ebc3ef04985b9f90e43fa6eaa14fa8.jpg
# 54ebc3ef04985b9f90e43fa6eaa14fa8.jpg
# 971ac9771e326e6572c4ea98ca657cce.jpg
# 971ac9771e326e6572c4ea98ca657cce.jpg
# 54f989487fabbbdbfe06f6042a4498b3.jpg
# 54f989487fabbbdbfe06f6042a4498b3.jpg
# cb910ec7cb858574baa143337da386ab.jpg
# cb910ec7cb858574baa143337da386ab.jpg
# 2092aab4552ced34ab4ac10f892790ca.jpg
# 2092aab4552ced34ab4ac10f892790ca.jpg
# b13eed5b43cf32b9adfdc4a4991e4293.jpg
# b13eed5b43cf32b9adfdc4a4991e4293.jpg
# 1accb31e811d72da3d870db1025a2580.jpg
# 1accb31e811d72da3d870db1025a2580.jpg

# %%
check = []
for i in random_numbers:
  if y[i] != train['image'][i]:
    check.append(i)
check
# Out:
# []

# %%
Image.open(img_path+train['image'][random_numbers[0]])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7F17C14D7B50>

# %%
# convert the image to array
X0 = X_ar[random_numbers[0]].reshape([64,64,3])
plt.imshow(X0)

# %%
Image.open(img_path+train['image'][random_numbers[5]])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800 at 0x7F17C135D910>

# %%
# convert the image to array
X0 = X_ar[random_numbers[5]].reshape([64,64,3])
plt.imshow(X0)
